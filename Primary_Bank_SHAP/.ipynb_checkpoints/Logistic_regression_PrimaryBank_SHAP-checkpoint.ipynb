# %%
#!pip install shap --upgrade

# %%
#!pip install pandas-profiling

# %%
#!pip install seaborn

# %%
#Based on the following article
#https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8

# %%
from pandas_profiling import ProfileReport

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc("font", size=14)
import pandas as pd
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
from azureml.core import Workspace, Dataset

subscription_id = '6ed9d167-b2e6-41b8-9500-35e6df64d9dc'
resource_group = 'MLRG'
workspace_name = 'erbbimlws'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='Primary_Bank')
df = dataset.to_pandas_dataframe()

# %%
#profile = ProfileReport(df.sample(frac = 0.1))
#profile

# %%
pd.set_option('max_columns', None) #display all columns
#pd.reset_option(“max_columns”) #to return to default

# %%
#df.head()

# %%
df['New_Primary_Bank_Flag'].value_counts().plot(kind = 'pie',y = 'New_Primary_Bank_Flag',figsize=(5, 5),title = 'New_Primary_Bank_Flag',autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'New_Primary_Bank_Flag'}, ylabel='New_Primary_Bank_Flag'>

# %%
df = df.drop(columns = ['Customer_ID','Year','Month','Legal_Person', 'Active_Customer', 'Priority_Segment',	'Primary_Bank','Group_Sales_Group_Code'])

# %%
def binF(x):
    if x is False:
        z = 0
    elif math.isnan(x):
        z = 0
    else:
        z =1
    return z

# %%
df['New_Primary_Bank_Flag'] = df['New_Primary_Bank_Flag'].apply(binF)

# %%
#dummy variables
for col in df.columns:       
       if df[col].dtypes=='object':
            df = pd.get_dummies(df, prefix=col + '_', columns=[col])

# %%
for col in df.columns:       
       if df[col].dtypes=='datetime64[ns]':
            df = df.drop(columns = col)

# %%
x_train, x_test, y_train, y_test = train_test_split(df.loc[:,df.columns !='New_Primary_Bank_Flag'].fillna(0), df['New_Primary_Bank_Flag'].fillna(0), test_size=0.25, random_state=0)

# %%
LR = LogisticRegression(penalty="l1", C=0.1,solver = 'liblinear')

# %%
LR.fit(x_train,y_train)
# Out:
# LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
print(classification_report(y_train,  LR.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76      7453
#            1       0.81      0.83      0.82      9796
#
#     accuracy                           0.79     17249
#    macro avg       0.79      0.79      0.79     17249
# weighted avg       0.79      0.79      0.79     17249

# %%
print('Accuracy of logistic regression classifier on train set: {:.4f}'.format(LR.score(x_train, y_train)))
# Out:
# Accuracy of logistic regression classifier on train set: 0.7931

# %%
y_pred = LR.predict(x_test)

# %%
print(classification_report(y_test,  LR.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      2399
#            1       0.80      0.83      0.82      3351
#
#     accuracy                           0.78      5750
#    macro avg       0.78      0.77      0.77      5750
# weighted avg       0.78      0.78      0.78      5750

# %%
print('Accuracy of logistic regression classifier on test set: {:.4f}'.format(LR.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.7809

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[1714  685]
#  [ 575 2776]]

# %%
logit_roc_auc = roc_auc_score(y_train.to_numpy(), LR.predict(x_train))
fpr, tpr, thresholds = roc_curve(y_train.to_numpy(), LR.predict_proba(x_train)[:,1])
auc_train = roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='Logistic Regression - train (area = %0.2f)' % auc_train)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")

# %%
logit_roc_auc = roc_auc_score(y_test, LR.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, LR.predict_proba(x_test)[:,1])
auc_test = roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='Logistic Regression test (area = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")

# %%
explainer = shap.LinearExplainer(LR, x_train)
shap_values = explainer.shap_values(x_test)
x_test_array = x_test.to_numpy() # we need to pass a dense version for the plotting functions

# %%
shap.summary_plot(shap_values, x_test_array,x_test.columns)

# %%
shap_values.shape
# Out:
# (5750, 438)

# %%
shap.plots.

# %%
help(shap.plots)
# Out:
# Help on package shap.plots in shap:
#
# NAME
#     shap.plots
#
# PACKAGE CONTENTS
#     _bar
#     _beeswarm
#     _benchmark
#     _decision
#     _embedding
#     _force
#     _force_matplotlib
#     _group_difference
#     _heatmap
#     _image
#     _labels
#     _monitoring
#     _partial_dependence
#     _scatter
#     _text
#     _utils
#     _violin
#     _waterfall
#     colors (package)
#
# SUBMODULES
#     bar
#     colorconv
#     decision
#     dependence
#     embedding
#     force
#     force_matplotlib
#     image
#     monitoring
#     partial_dependence
#     summary
#     waterfall
#
# DATA
#     labels = {'FEATURE': 'Feature %s', 'FEATURE_VALUE': 'Feature value', '...
#
# FILE
#     /anaconda/envs/azureml_py36/lib/python3.6/site-packages/shap/plots/__init__.py

# %%
parameters_dict = LR.get_params(deep=True)

# %%
parameters_dict
# Out:
# {'C': 0.1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l1',
#  'random_state': None,
#  'solver': 'liblinear',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
odds = np.exp(LR.coef_[0])
df_coef = pd.DataFrame(odds,x_test.columns,columns=['coef']).sort_values(by='coef', ascending=False)

# %%
pd.set_option("max_rows", None) #display all rows
#pd.reset_option('max_rows') #return to default settings

# %%
df_coef.head(10000)
# Out:
#                                                         coef
# LifeStage_Segment__02. Youth                        1.751533
# Education__a. Elementary School                     1.601995
# Fee_based_Services                                  1.572803
# Group_Sales_Flag                                    1.522913
# Education__b. Middle School                         1.517803
# Occupation__Οικιακά                                 1.516582
# EBanking_Transaction_Segment__5. Non Users          1.306238
# Debit_Cards_Prepaid_Cards                           1.300065
# SubSubSegment__Νέος 18-28 ετών                      1.288816
# Segment__Personal Banking                           1.288805
# SubSubSegment__Συνταξιοδοτούμενος                   1.286968
# Occupation__Νέοι                                    1.238535
# Remitances_Outgoing_flag                            1.223002
# Remitances_Incoming_flag                            1.221576
# SubSubSegment__Μισθοδοτούμενος Δημόσιος Υπάλληλος   1.202828
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.198240
# SubSubSegment__Λοιποί Πελάτες                       1.188290
# Education__c. High School                           1.169187
# Total_Card_Purchases_Num_Sum_6M_Band__6. 61 - 100   1.158287
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.134682
# Total_Card_Purchases_Num_Sum_6M_Band__7. 101 - 200  1.133648
# Bucket_Max_1M_Band__00                              1.119807
# Trn_ChecksOther_Num_Sum_6M                          1.116623
# Consumer_Segment__Students & Young Adults           1.113066
# New_CSI                                             1.091799
# Age_Band__07. 76-85                                 1.083751
# Payments_Flag                                       1.077879
# General_Insurances                                  1.071776
# EB_Trn_DOY_Payments_Days_Count_6M                   1.070159
# Total_Card_Purchases_Num_Sum_6M_Band__5. 36 - 60    1.067338
# EBanking_Transaction_Segment__1. Frequent           1.057099
# EB_Trn_DEKO_Payments_Days_Count_6M                  1.056441
# Home_Loans                                          1.056185
# Transactional_Saving_Accounts                       1.044551
# Trn_Withdrawal_Days_Count_6M                        1.042574
# ATM_Transactions_Days_Count_6M_Band__4. 7 - 9       1.042165
# Group_Sales_Payment_Months_Distinct_6M              1.040818
# EB_Trn_Out_Remmitance_GR_Days_Count_6M              1.039980
# Income_Segment__03. Medium Low                      1.037456
# Trn_EurolifePayment_Num_Sum_6M                      1.036954
# EB_Trn_Insurance_Payments_Num_Sum_6M                1.035298
# Branch_Transactions_Days_Count_6M_Band__1. 1 - 2    1.031757
# ATM_Trans_Num_Sum_6M                                1.031114
# Ex_Group_Sales_Flag                                 1.030189
# APS_Trans_Num_Sum_6M                                1.027005
# Consumer_Segment__Surviving Retirees                1.024799
# Trn_Remmitances_In_GR_Days_Count_6M                 1.024332
# Bucket_Months_Count_1Y                              1.024200
# Debit_Trans_Days_Count_6M                           1.021967
# Trn_Taxpayments_Days_Count_6M                       1.021742
# Payments_Trans_Days_Count_6M                        1.019433
# Branch_Trans_Num_Sum_6M                             1.019387
# EB_Trn_Public_Insurance_Payments_Num_Sum_6M         1.018965
# SubSegment__Prime                                   1.018568
# ATM_Transactions_Days_Count_6M_Band__5. 10 - 14     1.016986
# EB_Trans_Days_Count_6M                              1.015722
# Payments_Trans_Num_Sum_6M                           1.015162
# Total_Loans_Balances_OutStanding_1M_Band__01. 0...  1.014688
# Debit_Trans_Num_Sum_6M                              1.014244
# Remmitances_In_nonGR_Num_Sum_1Y                     1.013729
# Credit_Trans_Num_Sum_6M                             1.012208
# Trn_InternalTransfer_Num_Sum_6M                     1.010478
# DC_HouseNeeds_Purchases_Num_Sum_6M                  1.010079
# Group_Sales_Payments_Num_Sum_6M                     1.009634
# EB_Trn_Transfer_Other_ERB_Num_Sum_6M                1.008875
# Trn_OtherPrivateSectorPayments_Num_Sum_6M           1.008004
# Epistofi_Purchases_Num_Sum_6M                       1.005143
# CC_HouseNeeds_Purchases_Num_Sum_6M                  1.005115
# ATM_Trans_Days_Count_6M                             1.004628
# CC_BasicNeeds_Purchases_Num_Sum_6M                  1.003898
# Remittance_Trans_Num_Sum_6M                         1.003689
# EB_Trn_Login_Days_Count_6M                          1.003308
# EB_Trn_Prepaid_Fill_Amount_Sum_6M                   1.003125
# Trn_TelecomPayment_Amount_Sum_6M                    1.002629
# Minimum_ATM_Distance_NWD                            1.002409
# Epistofi_Redeemed_Amount_Max_6M                     1.002231
# DC_PersonalNeeds_Purchases_Num_Sum_6m               1.001857
# Total_Trans_Days_Count_6M                           1.001680
# Group_Sales_Active_Flag                             1.001462
# EB_Trn_Login_Num_Sum_6M                             1.000981
# CC_BasicNeeds_Purchases_Amount_Max_6M               1.000851
# Remmitances_In_nonGR_DaysSince_1Y                   1.000807
# DC_HouseNeeds_Purchases_Amount_Max_6M               1.000789
# DC_PersonalNeeds_Purchases_Amount_Max_6M            1.000780
# Trn_OtherPublicSectorPayment_Amount_Sum_6M          1.000683
# Trn_CashAdvance_Amount_Sum_6M                       1.000428
# Remmitances_Out_nonGR_DaysSince_1Y                  1.000410
# CC_Total_Purchases_Num_Sum_6M                       1.000402
# Minimum_ATM_Distance                                1.000364
# Total_Loans_Balances_OutStanding_1M_Band__03. 2...  1.000362
# Trn_DEKOPayment_Amount_Sum_6M                       1.000207
# Remmitances_In_GR_DaysSince_1Y                      1.000198
# DC_BasicNeeds_Purchases_Amount_Sum_6M               1.000163
# Trn_ImportsExports_Amount_Sum_6M                    1.000158
# Trn_Withdrawal_Amount_Sum_6M                        1.000083
# CC_HouseNeeds_Purchases_Amount_Sum_6M               1.000076
# Trn_InternalTransfer_Amount_Sum_6M                  1.000076
# Trn_Taxpayments_Amount_Sum_6M                       1.000076
# Trn_EurobankCheckDeposit_Amount_Sum_6M              1.000074
# Trn_Deposit_Amount_Sum_6M                           1.000065
# Remittance_Trans_Amount_Sum_6M                      1.000062
# EB_Trn_Payroll_Amount_Sum_6M                        1.000055
# Payments_Trans_Amount_Sum_6M                        1.000049
# Credit_Trans_Amount_Sum_6M                          1.000046
# Trn_TimeDeposit_Amount_Sum_6M                       1.000045
# Trn_OtherbankCheckDeposit_Amount_Sum_6M             1.000045
# Trn_ChecksOther_Amount_Sum_6M                       1.000044
# Trn_Checkpayment_Amount_Sum_6M                      1.000043
# Trn_Remmitances_Out_nonGR_Amount_Sum_6M             1.000040
# CC_PersonalNeeds_Purchases_Amount_Sum_6M            1.000039
# Phone_Trans_Amount_Sum_6M                           1.000037
# Trn_Other_Amount_Sum_6M                             1.000037
# EB_Trn_Other_Payments_Amount_Sum_6M                 1.000036
# Trn_Remmitances_Out_GR_Amount_Sum_6M                1.000034
# Checks_Issued_Last_1Y_Amount                        1.000034
# DC_Total_Purchases_Amount_Sum_6M                    1.000032
# Group_Sales_Salary_Avg_6M                           1.000030
# EB_Trn_DEKO_Payments_Amount_Sum_6M                  1.000025
# CC_PersonalNeeds_Purchases_Amount_Max_6M            1.000022
# CC_Total_Purchases_Amount_Sum_6M                    1.000021
# Remmitances_Out_nonGR_Amount_Sum_1Y                 1.000017
# Remmitances_In_GR_Amount_Sum_1Y                     1.000015
# Remmitances_Out_nonGR_Amount_Max_1Y                 1.000013
# Debit_Trans_Amount_Sum_6M                           1.000013
# EB_Trn_Credit_Card_Payments_Amount_Sum_6M           1.000010
# Total_Funds_Balance_Max_Ever                        1.000006
# Total_Deposits_All_Beneficieries_Balances_Avg_1M    1.000006
# POS_Balance_Sum_1Y                                  1.000004
# EB_Trn_New_eDeposit_Amount_Sum_6M                   1.000004
# DC_Total_Purchases_Num_Sum_6M                       1.000003
# EB_Trans_Amount_Sum_6M                              1.000003
# Total_Funds_Balances_Avg_1M                         1.000002
# Total_Loans_Balances_OutStanding_1M                 1.000002
# EB_Trn_Transfer_Own_Amount_Sum_6M                   1.000001
# Trn_OtherPrivateSectorPayments_Amount_Sum_6M        1.000001
# mBanking_Trans_Amount_Sum_6M                        1.000001
# SubSubSegment__Πληροφορική                          1.000000
# RA_Account_Number_Count_1M                          1.000000
# SubSubSegment__Πρωτογενής Τομέας                    1.000000
# Digital_Banking                                     1.000000
# SubSubSegment__Συνταξιούχος                         1.000000
# SubSubSegment__Υπηρεσίες                            1.000000
# Epistrofi_Redemptions_Flag                          1.000000
# SubSubSegment__Ναυτιλία                             1.000000
# SubSubSegment__Χονδρικό εμπόριο                     1.000000
# Other_SB_Services                                   1.000000
# Phone_Banking_Flag                                  1.000000
# Minimum_Branch_Distance_WD                          1.000000
# SubSubSegment__Hotel & Leisure                      1.000000
# Gender__FEMALE                                      1.000000
# SubSubSegment__Κατασκευές & Ακίνητα                 1.000000
# SubSegment__Standard TAG                            1.000000
# SubSegment__Risk                                    1.000000
# SubSegment__Prime Prospect                          1.000000
# SubSubSegment__Non Retail                           1.000000
# SubSegment__Prime Inactive                          1.000000
# SubSubSegment__Staff                                1.000000
# SubSubSegment__Εισοδηματίας                         1.000000
# SubSubSegment__Ελ. Επαγγελματίες                    1.000000
# SubSubSegment__Ιδιώτες                              1.000000
# SubSegment__Non Retail                              1.000000
# Gender__NON APPLICABLE                              1.000000
# SubSubSegment__Λιανικό εμπόριο                      1.000000
# SubSegment__Inactive Ιδιώτες                        1.000000
# SubSubSegment__Λοιποί κλάδοι                        1.000000
# Segment__Small Business                             1.000000
# SubSubSegment__Μεταποίηση                           1.000000
# SubSubSegment__Μη διαθέσιμο                         1.000000
# Segment__Non Retail                                 1.000000
# SubSegment__Standard Top                            1.000000
# Segment__Inactive Retail Customers                  1.000000
# SubSubSegment__Μη εργαζόμενος                       1.000000
# Total_Funds_Balances_Avg_1M_Band__12. 200.000 -...  1.000000
# Education__d. Technical School                      1.000000
# Total_Loans_Balances_OutStanding_1M_Band__13. >...  1.000000
# ATM_Transactions_Days_Count_6M_Band__7. >20         1.000000
# ATM_Transactions_Days_Count_6M_Band__6. 15 - 20     1.000000
# ATM_Transactions_Days_Count_6M_Band__3. 4 - 6       1.000000
# ATM_Transactions_Days_Count_6M_Band__1. 1           1.000000
# Branch_Transactions_Days_Count_6M_Band__4. >15      1.000000
# Branch_Transactions_Days_Count_6M_Band__3. 8 - 15   1.000000
# Branch_Transactions_Days_Count_6M_Band__2. 3- 7     1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Bucket_Max_1M_Band__01-02                           1.000000
# Bucket_Max_1M_Band__03                              1.000000
# Bucket_Max_1M_Band__04+                             1.000000
# Consumer_Segment__Tight Budget Families             1.000000
# Total_Card_Purchases_Num_Sum_6M_Band__4. 16 - 35    1.000000
# Channel_Usage_Segment__04. Digital                  1.000000
# Channel_Usage_Segment__03. Hybrid                   1.000000
# Channel_Usage_Segment__02. Physical                 1.000000
# Channel_Usage_Segment__01. Inactive                 1.000000
# Consumer_Segment__Young Workforce                   1.000000
# Consumer_Segment__Poorer Group                      1.000000
# Income_Segment__04. Low                             1.000000
# Consumer_Segment__Affluent Shoppers                 1.000000
# Consumer_Segment__Affluent Retirees                 1.000000
# Consumer_Segment__Affluent Families                 1.000000
# LifeStage_Segment__09. Legal Entity                 1.000000
# LifeStage_Segment__06. Pensioners                   1.000000
# LifeStage_Segment__04. Families                     1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__12. 2...  1.000000
# Education__g. PhD                                   1.000000
# Total_Loans_Balances_OutStanding_1M_Band__11. 1...  1.000000
# Age_Band__08. 86-100                                1.000000
# Age_Band__06. 66-75                                 1.000000
# Age_Band__02. 26-35                                 1.000000
# Age_Band__01. <=25                                  1.000000
# Marital_Status__n/a                                 1.000000
# Marital_Status__Widow                               1.000000
# Marital_Status__Single                              1.000000
# Marital_Status__Married                             1.000000
# Marital_Status__Divorced                            1.000000
# Marital_Status__Cohabit                             1.000000
# Occupation__Μη εργαζόμενος                          1.000000
# Occupation__ΚΕΝΟ                                    1.000000
# Occupation__Εισοδηματίας                            1.000000
# Occupation__Δημόσιοι Υπάλληλοι                      1.000000
# Occupation__n/a                                     1.000000
# Age_Band__n/a                                       1.000000
# EBanking_Transaction_Segment__4. Viewers            1.000000
# Total_Funds_Balances_Avg_1M_Band__01. 0 - 50€       1.000000
# Total_Funds_Balances_Avg_1M_Band__13. >500.000€     1.000000
# Total_Loans_Balances_OutStanding_1M_Band__10. 5...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__09. 2...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__08. 1...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__06. 2...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__05. 1...  1.000000
# Total_Loans_Balances_OutStanding_1M_Band__04. 5...  1.000000
# Total_Funds_Balances_Avg_1M_Band__11. 100.000 -...  1.000000
# Total_Funds_Balances_Avg_1M_Band__02. 50 - 200€     1.000000
# Total_Funds_Balances_Avg_1M_Band__10. 50.000 - ...  1.000000
# Total_Funds_Balances_Avg_1M_Band__09. 20.000 - ...  1.000000
# Total_Funds_Balances_Avg_1M_Band__08. 10.000 - ...  1.000000
# Total_Funds_Balances_Avg_1M_Band__07. 5.000 - 1...  1.000000
# Total_Funds_Balances_Avg_1M_Band__06. 2.000 - 5...  1.000000
# Total_Funds_Balances_Avg_1M_Band__03. 200 - 500€    1.000000
# POS                                                 1.000000
# SB_Customer                                         1.000000
# Credit_Cards                                        1.000000
# Trn_EnergyPayment_Days_Count_6M                     1.000000
# Trn_LoanCardPayment_Days_Count_6M                   1.000000
# Trn_Other_Num_Sum_6M                                1.000000
# Trn_Other_Days_Count_6M                             1.000000
# Business_loans_Long_Term                            1.000000
# Trn_TelecomPayment_Num_Sum_6M                       1.000000
# Trn_TelecomPayment_Days_Count_6M                    1.000000
# Trn_DEKOPayment_Num_Sum_6M                          1.000000
# Trn_DEKOPayment_Days_Count_6M                       1.000000
# Trn_OtherPublicSectorPayment_Num_Sum_6M             1.000000
# Trn_OtherPublicSectorPayment_Days_Count_6M          1.000000
# Trn_Taxpayments_Num_Sum_6M                          1.000000
# Trn_CashAdvance_Num_Sum_6M                          1.000000
# Trn_MunicipalitiesPayment_Num_Sum_6M                1.000000
# Trn_MunicipalitiesPayment_Days_Count_6M             1.000000
# Trn_EurolifePayment_Amount_Sum_6M                   1.000000
# Trn_EurolifePayment_Days_Count_6M                   1.000000
# Trn_ImportsExports_Num_Sum_6M                       1.000000
# Trn_ImportsExports_Days_Count_6M                    1.000000
# EB_Trn_Credit_Card_Payments_Num_Sum_6M              1.000000
# EB_Trn_Insurance_Payments_Days_Count_6M             1.000000
# EB_Trn_Investment_Num_Sum_6M                        1.000000
# EB_Trn_Investment_Days_Count_6M                     1.000000
# Trn_CashAdvance_Days_Count_6M                       1.000000
# Trn_TimeDeposit_Days_Count_6M                       1.000000
# EB_Trn_New_eDeposit_Num_Sum_6M                      1.000000
# Remittance_Trans_Days_Count_6M                      1.000000
# Bucket_Max_1M                                       1.000000
# Checks_Issued_Last_1Y_Num                           1.000000
# Remmitances_Out_nonGR_Num_Sum_1Y                    1.000000
# Rescheduling_Flag                                   1.000000
# SafeBox_active                                      1.000000
# Branch_Trans_Days_Count_6M                          1.000000
# APS_Trans_Days_Count_6M                             1.000000
# LivePay_Trans_Num_Sum_6M                            1.000000
# LivePay_Trans_Amount_Sum_6M                         1.000000
# LivePay_Trans_Days_Count_6M                         1.000000
# Trn_Deposit_Num_Sum_6M                              1.000000
# Trn_EurobankCheckIssue_Days_Count_6M                1.000000
# Trn_InternalTransfer_Days_Count_6M                  1.000000
# Trn_EurobankCheckDeposit_Num_Sum_6M                 1.000000
# Trn_EurobankCheckDeposit_Days_Count_6M              1.000000
# Trn_Checkpayment_Num_Sum_6M                         1.000000
# Trn_Checkpayment_Days_Count_6M                      1.000000
# Trn_OtherbankCheckDeposit_Num_Sum_6M                1.000000
# Trn_OtherbankCheckDeposit_Days_Count_6M             1.000000
# Trn_ChecksOther_Days_Count_6M                       1.000000
# Trn_EurobankCheckIssue_Num_Sum_6M                   1.000000
# Trn_EurobankCheckIssue_Amount_Sum_6M                1.000000
# EB_Trn_Loan_Payment_Days_Count_6M                   1.000000
# Trn_OtherInsurancePayments_Days_Count_6M            1.000000
# EB_Trn_New_eDeposit_Days_Count_6M                   1.000000
# EB_Trn_Out_Remmitance_Abroad_Num_Sum_6M             1.000000
# EB_Trn_Payroll_Num_Sum_6M                           1.000000
# EB_Trn_Payroll_Days_Count_6M                        1.000000
# EB_Trn_Prepaid_Fill_Num_Sum_6M                      1.000000
# EB_Trn_Prepaid_Fill_Days_Count_6M                   1.000000
# EB_Trn_Public_Insurance_Payments_Days_Count_6M      1.000000
# EB_Trn_Transfer_Own_Num_Sum_6M                      1.000000
# Trn_Remmitances_Out_GR_Days_Count_6M                1.000000
# Trn_Remmitances_Out_nonGR_Num_Sum_6M                1.000000
# Trn_Remmitances_Out_nonGR_Days_Count_6M             1.000000
# Trn_Remmitances_In_GR_Num_Sum_6M                    1.000000
# Trn_Remmitances_In_nonGR_Days_Count_6M              1.000000
# Active_Payroll_Pension_Accounts                     1.000000
# Time_Deposits                                       1.000000
# Pension_Investment_Insurances                       1.000000
# Business_loans_Short_Term                           1.000000
# EB_Trn_Out_Remmitance_Abroad_Days_Count_6M          1.000000
# Total_Card_Purchases_Num_Sum_6M_Band__8. >200       1.000000
# EB_Trn_Other_Transactions_Num_Sum_6M                1.000000
# EB_Trn_Other_Payments_Days_Count_6M                 1.000000
# EB_Trn_Other_Payments_Num_Sum_6M                    1.000000
# EB_Trn_Other_Transactions_Days_Count_6M             1.000000
# Remmitances_In_nonGR_Amount_Sum_1Y                  1.000000
# Total_Funds_All_Beneficieries_Balances_Avg_1M       0.999997
# Total_Funds_Balance_Min_Ever                        0.999997
# Trn_LoanCardPayment_Amount_Sum_6M                   0.999995
# EB_Trn_Investment_Amount_Sum_6M                     0.999995
# EB_Trn_Out_Remmitance_GR_Amount_Sum_6M              0.999995
# Total_Deposits_Balances_Avg_1M                      0.999995
# EB_Trn_Transfer_Other_ERB_Amount_Sum_6M             0.999994
# Trn_Remmitances_In_nonGR_Amount_Sum_6M              0.999994
# Total_Trans_Amount_Sum_6M                           0.999992
# Remmitances_In_nonGR_Amount_Max_1Y                  0.999992
# Remmitances_Out_GR_Amount_Sum_1Y                    0.999991
# Remmitances_Out_GR_Amount_Max_1Y                    0.999991
# EB_Trn_DOY_Payments_Amount_Sum_6M                   0.999985
# EB_Trn_Out_Remmitance_Abroad_Amount_Sum_6M          0.999984
# Remmitances_In_GR_1Y_Amount_Max_1Y                  0.999981
# APS_Trans_Amount_Sum_6M                             0.999980
# DC_PersonalNeeds_Purchases_Amount_Sum_6M            0.999978
# Trn_Remmitances_In_GR_Amount_Sum_6M                 0.999976
# EB_Trn_Public_Insurance_Payments_Amount_Sum_6M      0.999974
# CC_BasicNeeds_Purchases_Amount_Sum_6M               0.999966
# Checks_Issued_MaxAmount_1Y                          0.999963
# EB_Trn_Loan_Payment_Amount_Sum_6M                   0.999945
# CC_Total_Purchases_Amount_Max_6M                    0.999932
# Branch_Trans_Amount_Sum_6M                          0.999917
# DC_HouseNeeds_Purchases_Amount_Sum_6M               0.999916
# ATM_Trans_Amount_Sum_6M                             0.999895
# mBanking_Logins_Num_Sum_6M                          0.999880
# EB_Trn_Insurance_Payments_Amount_Sum_6M             0.999846
# Trn_OtherInsurancePayments_Amount_Sum_6M            0.999825
# CC_HouseNeeds_Purchases_Amount_Max_6M               0.999809
# Minimum_Branch_Distance                             0.999794
# Checks_Issued_DaysSince_1Y                          0.999701
# Trn_EnergyPayment_Amount_Sum_6M                     0.999647
# DC_BasicNeeds_Purchases_Amount_Max_6M               0.999485
# Remmitances_Out_GR_DaysSince_1Y                     0.999479
# Minimum_ATM_Distance_WD                             0.999419
# CC_PersonalNeeds_Purchases_Num_Sum_6M               0.999298
# DC_Total_Purchases_Amount_Max_6M                    0.999224
# Days_Since_Last_Transaction                         0.999102
# Remmitances_Out_GR_Num_Sum_1Y                       0.998885
# mBanking_Trans_Num_Sum_6M                           0.998876
# EB_Trn_Other_Transactions_Amount_Sum_6M             0.998737
# DC_BasicNeeds_Purchases_Num_Sum_6M                  0.998558
# ATM_Transactions_Days_Count_6M_Band__0. 0           0.998500
# Epistofi_Redeemed_Amount_Sum_6M                     0.998439
# Trn_MunicipalitiesPayment_Amount_Sum_6M             0.998301
# Total_Funds_Balances_Avg_1M_Band__04. 500 - 1.000€  0.997955
# Trn_TimeDeposit_Num_Sum_6M                          0.997901
# Minimum_Branch_Distance_NWD                         0.997715
# EB_Trans_Num_Sum_6M                                 0.996508
# Trn_Remmitances_In_nonGR_Num_Sum_6M                 0.996239
# Personal_loans                                      0.996196
# Total_Trans_Num_Sum_6M                              0.996081
# Epistofi_Points_Amount_Sum_6M                       0.995680
# EB_Trn_Loan_Payment_Num_Sum_6M                      0.994652
# EB_Trn_DEKO_Payments_Num_Sum_6M                     0.994611
# EB_Trn_Transfer_Own_Days_Count_6M                   0.994372
# Investments                                         0.993035
# LifeStage_Segment__05. Active Mature                0.992003
# EB_Trn_Credit_Card_Payments_Days_Count_6M           0.991496
# EB_Trn_DOY_Payments_Num_Sum_6M                      0.990704
# Trn_Deposit_Days_Count_6M                           0.989035
# Trn_Remmitances_Out_GR_Num_Sum_6M                   0.988318
# Remmitances_In_GR_Num_Sum_1Y                        0.987898
# Total_Funds_Balances_Avg_1M_Band__05. 1.000 - 2...  0.986190
# Epistofi_Redemptions_Num_Sum_6M                     0.986004
# EB_Trn_Out_Remmitance_GR_Num_Sum_6M                 0.985319
# Bucket_Max_1M_Band__-1                              0.984371
# EB_Trn_Transfer_Other_ERB_Days_Count_6M             0.983136
# Phone_Trans_Days_Count_6M                           0.982444
# Trn_LoanCardPayment_Num_Sum_6M                      0.982431
# Trn_EnergyPayment_Num_Sum_6M                        0.981196
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  0.980707
# Age                                                 0.980395
# mBanking_Flag                                       0.978812
# Education__f. MSc                                   0.978404
# Education__e. University                            0.977599
# SubSubSegment__Ελεύθερος Επαγγελματίας              0.976264
# LifeStage_Segment__03. Bachelors                    0.975096
# Life_Health_Insurances                              0.974017
# Total_Loans_Balances_OutStanding_1M_Band__02. 5...  0.965310
# Trn_OtherInsurancePayments_Num_Sum_6M               0.963994
# ATM_Transactions_Days_Count_6M_Band__2. 2 - 3       0.963936
# EBanking_Transaction_Segment__2. Typical            0.963048
# Credit_Trans_Days_Count_6M                          0.962588
# Age_Band__05. 56-65                                 0.958428
# Phone_Trans_Num_Sum_6M                              0.947975
# Credit_Limit_Utilization_Perc_6M                    0.945114
# Occupation__Ιδιωτικοί Υπάλληλοι                     0.929575
# Trn_Withdrawal_Num_Sum_6M                           0.924003
# Consumer_Segment__Emerging Eagles                   0.920745
# Total_Loans_Balances_OutStanding_1M_Band__07. 5...  0.913308
# Occupation__Ελεύθεροι Επαγγελματίες                 0.912875
# Age_Band__04. 46-55                                 0.901671
# SubSubSegment__Μισθοδοτούμενος Ιδιωτικός Υπάλληλος  0.899082
# Bucket_Max_1Y                                       0.894898
# Segment__Individual Banking                         0.891389
# Total_Card_Purchases_Num_Sum_6M_Band__2. 3 - 7      0.890196
# Trn_OtherPrivateSectorPayments_Days_Count_6M        0.875243
# Total_Card_Purchases_Num_Sum_6M_Band__3. 8 - 15     0.874095
# Epistrofi_Purchases_Num_Perc_6M                     0.871212
# Education__n/a                                      0.851075
# Branch_Transactions_Days_Count_6M_Band__0. 0        0.842720
# SubSegment__Standard                                0.839245
# SubSubSegment__Μισθωτός Ιδιωτικός Υπάλληλος         0.827521
# Gender__MALE                                        0.821444
# EBanking_Transaction_Segment__3. Occasional         0.804429
# Income_Segment__02. Medium                          0.803289
# Age_Band__03. 36-45                                 0.802934
# Total_Funds_All_Beneficieries_Balances_Avg_1M_B...  0.797270
# Income_Segment__01. Top                             0.759585
# Total_Card_Purchases_Num_Sum_6M_Band__1. 1 - 2      0.746640
# Occupation__Συνταξιούχοι                            0.713128
# Total_Card_Purchases_Num_Sum_6M_Band__0. 0          0.668282
# SubSubSegment__Μισθωτός Δημόσιος Υπάλληλος          0.435972
